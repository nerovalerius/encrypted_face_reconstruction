# %%
# dependencies
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
########################################################################
# VISUALLY COMPARE GENERATED FACES
########################################################################

####################################
# LOAD IMAGES
####################################
plain_faces = []
encrypted_r_faces = []
encrypted_l_faces = []
r_enc_trained_r_psp = []
l_enc_trained_r_psp = []
r_enc_trained_l_psp = []
l_enc_trained_l_psp = []
r_enc_trained_pre_psp = []
l_enc_trained_pre_psp = []

plain_faces.append(cv2.imread('original_and_generated_faces/original/plain/501181/501181_490207.jpg'))
plain_faces.append(cv2.imread('original_and_generated_faces/original/plain/501182/501182_490230.jpg'))
plain_faces.append(cv2.imread('original_and_generated_faces/original/plain/501183/501183_490245.jpg'))
plain_faces.append(cv2.imread('original_and_generated_faces/original/plain/501184/501184_490275.jpg'))
plain_faces.append(cv2.imread('original_and_generated_faces/original/plain/501185/501185_490301.jpg'))

encrypted_r_faces.append(cv2.imread('original_and_generated_faces/original/r_encrypted/501181/501181_490207_j2k_r-W4-O6.png'))
encrypted_r_faces.append(cv2.imread('original_and_generated_faces/original/r_encrypted/501182/501182_490230_j2k_r-W4-O6.png'))
encrypted_r_faces.append(cv2.imread('original_and_generated_faces/original/r_encrypted/501183/501183_490245_j2k_r-W4-O6.png'))
encrypted_r_faces.append(cv2.imread('original_and_generated_faces/original/r_encrypted/501184/501184_490275_j2k_r-W4-O6.png'))
encrypted_r_faces.append(cv2.imread('original_and_generated_faces/original/r_encrypted/501185/501185_490301_j2k_r-W4-O6.png'))

encrypted_l_faces.append(cv2.imread('original_and_generated_faces/original/l_encrypted/501181/501181_490207_j2k_l-W4-O6.png'))
encrypted_l_faces.append(cv2.imread('original_and_generated_faces/original/l_encrypted/501182/501182_490230_j2k_l-W4-O6.png'))
encrypted_l_faces.append(cv2.imread('original_and_generated_faces/original/l_encrypted/501183/501183_490245_j2k_l-W4-O6.png'))
encrypted_l_faces.append(cv2.imread('original_and_generated_faces/original/l_encrypted/501184/501184_490275_j2k_l-W4-O6.png'))
encrypted_l_faces.append(cv2.imread('original_and_generated_faces/original/l_encrypted/501185/501185_490301_j2k_l-W4-O6.png'))

r_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_r/501181/501181_490207_j2k_r-W4-O6.png'))
r_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_r/501182/501182_490230_j2k_r-W4-O6.png'))
r_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_r/501183/501183_490245_j2k_r-W4-O6.png'))
r_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_r/501184/501184_490275_j2k_r-W4-O6.png'))
r_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_r/501185/501185_490301_j2k_r-W4-O6.png'))

l_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_r/501181/501181_490207_j2k_l-W4-O6.png'))
l_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_r/501182/501182_490230_j2k_l-W4-O6.png'))
l_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_r/501183/501183_490245_j2k_l-W4-O6.png'))
l_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_r/501184/501184_490275_j2k_l-W4-O6.png'))
l_enc_trained_r_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_r/501185/501185_490301_j2k_l-W4-O6.png'))

r_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_l/501181/501181_490207_j2k_r-W4-O6.png'))
r_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_l/501182/501182_490230_j2k_r-W4-O6.png'))
r_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_l/501183/501183_490245_j2k_r-W4-O6.png'))
r_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_l/501184/501184_490275_j2k_r-W4-O6.png'))
r_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/r_enc_trained_l/501185/501185_490301_j2k_r-W4-O6.png'))

l_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_l/501181/501181_490207_j2k_l-W4-O6.png'))
l_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_l/501182/501182_490230_j2k_l-W4-O6.png'))
l_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_l/501183/501183_490245_j2k_l-W4-O6.png'))
l_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_l/501184/501184_490275_j2k_l-W4-O6.png'))
l_enc_trained_l_psp.append(cv2.imread('original_and_generated_faces/psp/l_enc_trained_l/501185/501185_490301_j2k_l-W4-O6.png'))

r_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/r_pretrained/501181/501181_490207_gen.jpg'))
r_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/r_pretrained/501182/501182_490230_gen.jpg'))
r_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/r_pretrained/501183/501183_490245_gen.jpg'))
r_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/r_pretrained/501184/501184_490275_gen.jpg'))
r_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/r_pretrained/501185/501185_490301_gen.jpg'))

l_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/l_pretrained/501181/501181_490207_gen.jpg'))
l_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/l_pretrained/501182/501182_490230_gen.jpg'))
l_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/l_pretrained/501183/501183_490245_gen.jpg'))
l_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/l_pretrained/501184/501184_490275_gen.jpg'))
l_enc_trained_pre_psp.append(cv2.imread('original_and_generated_faces/psp/l_pretrained/501185/501185_490301_gen.jpg'))

print("images loaded")
# Out:
# images loaded

# %%
####################################################################
# PLOT IMAGES
####################################################################

################################
# PLAIN FACES
################################

fig = plt.figure(figsize=(25, 25))

print("1 - plain faces")
for i in range(1,len(plain_faces)+1):
    fig.add_subplot(9,5,i)
    plt.imshow(cv2.cvtColor(plain_faces[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# R ENCRYPTED FACES
################################

print("2 - r encrypted faces")
for i in range(1,len(encrypted_r_faces)+1):
    fig.add_subplot(9,5,i+5)
    plt.imshow(cv2.cvtColor(encrypted_r_faces[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# L ENCRYPTED FACES
################################

print("3 - l encrypted faces")
for i in range(1,len(encrypted_l_faces)+1):
    fig.add_subplot(9,5,i+10)
    plt.imshow(cv2.cvtColor(encrypted_l_faces[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# PSP R ENC FACES TRAINED WITH R
################################

print("4 - r encrypted faces generated with r trained model")
for i in range(1,len(r_enc_trained_r_psp)+1):
    fig.add_subplot(9,5,i+15)
    plt.imshow(cv2.cvtColor(r_enc_trained_r_psp[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# PSP L ENC FACES TRAINED WITH R
################################

print("5 - l encrypted faces generated with r trained model")
for i in range(1,len(l_enc_trained_r_psp)+1):
    fig.add_subplot(9,5,i+20)
    plt.imshow(cv2.cvtColor(l_enc_trained_r_psp[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# PSP R ENC FACES TRAINED WITH L
################################

print("6 - r encrypted faces generated with l trained model")
for i in range(1,len(r_enc_trained_l_psp)+1):
    fig.add_subplot(9,5,i+25)
    plt.imshow(cv2.cvtColor(r_enc_trained_l_psp[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# PSP L ENC FACES TRAINED WITH L
################################

print("7 - l encrypted faces generated with l trained model")
for i in range(1,len(l_enc_trained_l_psp)+1):
    fig.add_subplot(9,5,i+30)
    plt.imshow(cv2.cvtColor(l_enc_trained_l_psp[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# PSP R PRETRAINED
################################

print("8 - r encrypted faces generated with preb trained model")
for i in range(1,len(r_enc_trained_pre_psp)+1):
    fig.add_subplot(9,5,i+35)
    plt.imshow(cv2.cvtColor(r_enc_trained_pre_psp[i-1], cv2.COLOR_BGR2RGB))
    i += 1

################################
# PSP L PRETRAINED
################################

print("9 - l encrypted faces generated with preb trained model")
for i in range(1,len(l_enc_trained_pre_psp)+1):
    fig.add_subplot(9,5,i+40)
    plt.imshow(cv2.cvtColor(l_enc_trained_pre_psp[i-1], cv2.COLOR_BGR2RGB))
    i += 1
    
plt.tight_layout()
plt.show()
# Out:
# 1 - plain faces
# 2 - r encrypted faces
# 3 - l encrypted faces
# 4 - r encrypted faces generated with r trained model
# 5 - l encrypted faces generated with r trained model
# 6 - r encrypted faces generated with l trained model
# 7 - l encrypted faces generated with l trained model
# 8 - r encrypted faces generated with preb trained model
# 9 - l encrypted faces generated with preb trained model
